# %% [markdown]
# <a href="https://colab.research.google.com/github/iAmirHosein92/Class_Exercise_Solution/blob/main/S8_Exercises_Solutions/StackOverFlowSurveyResultsAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('./drive/MyDrive/survey_results_public.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
pd.set_option('display.max_columns', None)
df.sample(10)
# Out:
#        ResponseId                      MainBranch              Age  \
# 17680       17681  I am a developer by profession  18-24 years old
# 5514         5515  I am a developer by profession  25-34 years old
# 28602       28603  I am a developer by profession  25-34 years old
# 61184       61185  I am a developer by profession  35-44 years old
# 24416       24417  I am a developer by profession  25-34 years old
# 29761       29762  I am a developer by profession  25-34 years old
# 48874       48875     I code primarily as a hobby  35-44 years old
# 63768       63769  I am a developer by profession  18-24 years old
# 58267       58268  I am a developer by profession  25-34 years old
# 24016       24017  I am a developer by profession  35-44 years old
#
#                                               Employment  \
# 17680  Not employed, but looking for work;Student, pa...
# 5514                                 Employed, full-time
# 28602                                Employed, full-time
# 61184                                Employed, full-time
# 24416                                Employed, full-time
# 29761                                Employed, full-time
# 48874                                Employed, full-time
# 63768  Employed, full-time;Not employed, but looking ...
# 58267                                Employed, full-time
# 24016                                Employed, full-time
#
#                                  RemoteWork   Check  \
# 17680                                   NaN  Apples
# 5514   Hybrid (some remote, some in-person)  Apples
# 28602                                Remote  Apples
# 61184                                Remote  Apples
# 24416                                Remote  Apples
# 29761  Hybrid (some remote, some in-person)  Apples
# 48874                                Remote  Apples
# 63768                                Remote  Apples
# 58267  Hybrid (some remote, some in-person)  Apples
# 24016  Hybrid (some remote, some in-person)  Apples
#
#                                         CodingActivities  \
# 17680                                                NaN
# 5514   Hobby;Professional development or self-paced l...
# 28602  Hobby;Contribute to open-source projects;Freel...
# 61184                       I don’t code outside of work
# 24416  Hobby;Professional development or self-paced l...
# 29761                                              Hobby
# 48874                                              Hobby
# 63768  Hobby;Professional development or self-paced l...
# 58267  Hobby;Contribute to open-source projects;Profe...
# 24016                       I don’t code outside of work
#
#                                                  EdLevel  \
# 17680  Some college/university study without earning ...
# 5514        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28602       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 61184                                                NaN
# 24416       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 29761  Some college/university study without earning ...
# 48874  Some college/university study without earning ...
# 63768                                                NaN
# 58267       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 24016       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                LearnCode  \
# 17680  Other online resources (e.g., videos, blogs, f...
# 5514   On the job training;Other online resources (e....
# 28602  Other online resources (e.g., videos, blogs, f...
# 61184                                                NaN
# 24416  Books / Physical media;Colleague;On the job tr...
# 29761  Books / Physical media;On the job training;Oth...
# 48874  Books / Physical media;Other online resources ...
# 63768                                                NaN
# 58267                    Online Courses or Certification
# 24016  Books / Physical media;On the job training;Oth...
#
#                                          LearnCodeOnline  \
# 17680  Technical documentation;Blogs;Written Tutorial...
# 5514   Technical documentation;Blogs;Written Tutorial...
# 28602  Technical documentation;Written Tutorials;Stac...
# 61184                                                NaN
# 24416  Technical documentation;Blogs;Books;Written Tu...
# 29761  Technical documentation;Blogs;Written Tutorial...
# 48874  Books;Stack Overflow;Video-based Online Course...
# 63768                                                NaN
# 58267                                                NaN
# 24016  Technical documentation;Blogs;Books;Written Tu...
#
#                                                  TechDoc YearsCode  \
# 17680  API document(s) and/or SDK document(s);AI-powe...         2
# 5514   API document(s) and/or SDK document(s);User gu...        14
# 28602  User guides or README files found in the sourc...         9
# 61184                                                NaN       NaN
# 24416  API document(s) and/or SDK document(s);User gu...        13
# 29761  API document(s) and/or SDK document(s);User gu...        11
# 48874                                                NaN         9
# 63768                                                NaN       NaN
# 58267                                                NaN         3
# 24016  API document(s) and/or SDK document(s);User gu...        22
#
#            YearsCodePro                                      DevType  \
# 17680  Less than 1 year                        Developer, full-stack
# 5514                  7                        Developer, full-stack
# 28602                 6                          Developer, back-end
# 61184               NaN                                          NaN
# 24416                10  Developer, embedded applications or devices
# 29761                 7                        Developer, full-stack
# 48874               NaN                        Security professional
# 63768               NaN                                          NaN
# 58267                 3                                Developer, AI
# 24016                19                            DevOps specialist
#
#                         OrgSize              PurchaseInfluence  \
# 17680                       NaN                            NaN
# 5514         20 to 99 employees          I have some influence
# 28602      100 to 499 employees  I have little or no influence
# 61184                       NaN                            NaN
# 24416  1,000 to 4,999 employees  I have little or no influence
# 29761        20 to 99 employees          I have some influence
# 48874                       NaN                            NaN
# 63768                       NaN                            NaN
# 58267  1,000 to 4,999 employees  I have little or no influence
# 24016  5,000 to 9,999 employees          I have some influence
#
#                                               BuyNewTool  \
# 17680                                                NaN
# 5514   Start a free trial;Ask developers I know/work ...
# 28602  Ask developers I know/work with;Visit develope...
# 61184                                                NaN
# 24416  Start a free trial;Ask developers I know/work ...
# 29761  Start a free trial;Visit developer communities...
# 48874                                                NaN
# 63768                                                NaN
# 58267  Start a free trial;Ask developers I know/work ...
# 24016  Start a free trial;Ask a generative AI tool;Vi...
#
#                                               BuildvsBuy  \
# 17680                                                NaN
# 5514   Out-of-the-box is ready to go with little need...
# 28602  Is ready-to-go but also customizable for growt...
# 61184                                                NaN
# 24416  Is ready-to-go but also customizable for growt...
# 29761  Is set up to be customized and needs to be eng...
# 48874                                                NaN
# 63768                                                NaN
# 58267  Is set up to be customized and needs to be eng...
# 24016  Is set up to be customized and needs to be eng...
#
#                                              TechEndorse  \
# 17680                                                NaN
# 5514   APIs;Customization;Integrated developer commun...
# 28602          APIs;Customization;Quality support system
# 61184                                                NaN
# 24416  APIs;Quality support system;Reputation for qua...
# 29761  APIs;Customization;Integrated developer commun...
# 48874                                                NaN
# 63768                                                NaN
# 58267                                             Other:
# 24016  APIs;Customization;Integrated developer commun...
#
#                         Country                   Currency   CompTotal  \
# 17680                     Kenya                        NaN         NaN
# 5514                    Uruguay  USD\tUnited States dollar     40000.0
# 28602                   Romania          RON\tRomanian leu    276000.0
# 61184                       NaN                        NaN         NaN
# 24416  United States of America  USD\tUnited States dollar    123000.0
# 29761                  Colombia        COP\tColombian peso  60000000.0
# 48874                 Australia                        NaN         NaN
# 63768                       NaN                        NaN         NaN
# 58267                     India          INR\tIndian rupee         NaN
# 24016  United States of America  USD\tUnited States dollar    160000.0
#
#                                   LanguageHaveWorkedWith  \
# 17680  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 5514                            Dart;HTML/CSS;JavaScript
# 28602                                             C#;SQL
# 61184                                                NaN
# 24416  Assembly;Bash/Shell (all shells);C;C++;GDScrip...
# 29761  Bash/Shell (all shells);HTML/CSS;JavaScript;Ko...
# 48874  Bash/Shell (all shells);C++;Cobol;Fortran;Go;J...
# 63768                                                NaN
# 58267          HTML/CSS;JavaScript;Python;SQL;TypeScript
# 24016  Bash/Shell (all shells);Groovy;HTML/CSS;Java;J...
#
#                                   LanguageWantToWorkWith  \
# 17680  Bash/Shell (all shells);Dart;HTML/CSS;JavaScri...
# 5514                            Dart;HTML/CSS;JavaScript
# 28602                                             C#;SQL
# 61184                                                NaN
# 24416                           C++;GDScript;Python;Rust
# 29761                           Go;Kotlin;SQL;TypeScript
# 48874                                                NaN
# 63768                                                NaN
# 58267                                    C++;Java;MATLAB
# 24016                                                 Go
#
#                                          LanguageAdmired  \
# 17680  Bash/Shell (all shells);HTML/CSS;JavaScript;Ty...
# 5514                            Dart;HTML/CSS;JavaScript
# 28602                                             C#;SQL
# 61184                                                NaN
# 24416                                C++;GDScript;Python
# 29761                              Kotlin;SQL;TypeScript
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                                   DatabaseHaveWorkedWith  \
# 17680  Firebase Realtime Database;MongoDB;MySQL;Postg...
# 5514                                             MongoDB
# 28602          Cosmos DB;Microsoft SQL Server;PostgreSQL
# 61184                                                NaN
# 24416                                                NaN
# 29761                                         PostgreSQL
# 48874                                             Oracle
# 63768                                                NaN
# 58267              Elasticsearch;MySQL;Oracle;PostgreSQL
# 24016                                     MongoDB;Oracle
#
#                           DatabaseWantToWorkWith  \
# 17680   Firebase Realtime Database;MongoDB;MySQL
# 5514                                     MongoDB
# 28602  Cosmos DB;Microsoft SQL Server;PostgreSQL
# 61184                                        NaN
# 24416                                        NaN
# 29761                                        NaN
# 48874                                        NaN
# 63768                                        NaN
# 58267                                  Snowflake
# 24016                                        NaN
#
#                                  DatabaseAdmired  \
# 17680   Firebase Realtime Database;MongoDB;MySQL
# 5514                                     MongoDB
# 28602  Cosmos DB;Microsoft SQL Server;PostgreSQL
# 61184                                        NaN
# 24416                                        NaN
# 29761                                        NaN
# 48874                                        NaN
# 63768                                        NaN
# 58267                                        NaN
# 24016                                        NaN
#
#                              PlatformHaveWorkedWith  \
# 17680                       Firebase;Netlify;Vercel
# 5514   Firebase;Google Cloud;Heroku;Microsoft Azure
# 28602                               Microsoft Azure
# 61184                                           NaN
# 24416                                           NaN
# 29761                     Amazon Web Services (AWS)
# 48874                                           NaN
# 63768                                           NaN
# 58267                     Amazon Web Services (AWS)
# 24016                             Cloudflare;VMware
#
#                                   PlatformWantToWorkWith  \
# 17680  Amazon Web Services (AWS);Firebase;Google Clou...
# 5514   Amazon Web Services (AWS);Firebase;Google Clou...
# 28602                                    Microsoft Azure
# 61184                                                NaN
# 24416                                                NaN
# 29761                          Amazon Web Services (AWS)
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                          Amazon Web Services (AWS)
#
#                                     PlatformAdmired  \
# 17680                       Firebase;Netlify;Vercel
# 5514   Firebase;Google Cloud;Heroku;Microsoft Azure
# 28602                               Microsoft Azure
# 61184                                           NaN
# 24416                                           NaN
# 29761                     Amazon Web Services (AWS)
# 48874                                           NaN
# 63768                                           NaN
# 58267                                           NaN
# 24016                                           NaN
#
#                             WebframeHaveWorkedWith  \
# 17680  Express;Next.js;Node.js;React;Ruby on Rails
# 5514                                       Node.js
# 28602                          ASP.NET CORE;Blazor
# 61184                                          NaN
# 24416                                          NaN
# 29761                Django;NestJS;React;WordPress
# 48874              AngularJS;Node.js;Ruby on Rails
# 63768                                          NaN
# 58267                         Django;FastAPI;React
# 24016                                jQuery;Vue.js
#
#                              WebframeWantToWorkWith  \
# 17680  Express;FastAPI;jQuery;Next.js;Node.js;React
# 5514                                 NestJS;Node.js
# 28602                           ASP.NET CORE;Blazor
# 61184                                           NaN
# 24416                                           NaN
# 29761                                   Spring Boot
# 48874                                           NaN
# 63768                                           NaN
# 58267                                           NaN
# 24016                                           NaN
#
#                      WebframeAdmired            EmbeddedHaveWorkedWith  \
# 17680  Express;Next.js;Node.js;React                               NaN
# 5514                         Node.js                               NaN
# 28602            ASP.NET CORE;Blazor                               NaN
# 61184                            NaN                               NaN
# 24416                            NaN  CMake;GNU GCC;LLVM's Clang;Ninja
# 29761                            NaN                               NaN
# 48874                            NaN                               NaN
# 63768                            NaN                               NaN
# 58267                            NaN                               NaN
# 24016                            NaN                               NaN
#
#          EmbeddedWantToWorkWith EmbeddedAdmired  \
# 17680                       NaN             NaN
# 5514                        NaN             NaN
# 28602                       NaN             NaN
# 61184                       NaN             NaN
# 24416  LLVM's Clang;Rasberry Pi    LLVM's Clang
# 29761                       NaN             NaN
# 48874                       NaN             NaN
# 63768                       NaN             NaN
# 58267                       NaN             NaN
# 24016                       NaN             NaN
#
#                                   MiscTechHaveWorkedWith  \
# 17680                                                NaN
# 5514                                             Flutter
# 28602                                         .NET (5+)
# 61184                                                NaN
# 24416                                NumPy;Opencv;Pandas
# 29761                                                NaN
# 48874                        Apache Spark;OpenCL;SwiftUI
# 63768                                                NaN
# 58267  Apache Spark;CUDA;Hugging Face Transformers;Nu...
# 24016                                       Apache Kafka
#
#                                   MiscTechWantToWorkWith  \
# 17680                                                NaN
# 5514                                  Flutter;TensorFlow
# 28602                                         .NET (5+)
# 61184                                                NaN
# 24416                                  CUDA;NumPy;Opencv
# 29761                                                NaN
# 48874                                                NaN
# 63768                                                NaN
# 58267  Apache Kafka;Opencv;Scikit-Learn;TensorFlow;To...
# 24016                                                NaN
#
#                   MiscTechAdmired           ToolsTechHaveWorkedWith  \
# 17680                         NaN  Docker;Homebrew;npm;Vite;Webpack
# 5514                      Flutter                               npm
# 28602                  .NET (5+)               Docker;MSBuild;NuGet
# 61184                         NaN                               NaN
# 24416                NumPy;Opencv      Godot;Google Test;Make;Ninja
# 29761                         NaN          Gradle;npm;Pip;Vite;Yarn
# 48874                         NaN     Chef;Kubernetes;Unreal Engine
# 63768                         NaN                               NaN
# 58267  Scikit-Learn;Torch/PyTorch                               Pip
# 24016                         NaN    Ansible;Docker;Gradle;npm;Yarn
#
#             ToolsTechWantToWorkWith   ToolsTechAdmired  \
# 17680  Google Test;npm;Vite;Webpack   npm;Vite;Webpack
# 5514                     Docker;npm                npm
# 28602                         NuGet              NuGet
# 61184                           NaN                NaN
# 24416             Godot;Google Test  Godot;Google Test
# 29761                           NaN                NaN
# 48874                           NaN                NaN
# 63768                           NaN                NaN
# 58267                        Docker                NaN
# 24016   Kubernetes;Podman;Terraform                NaN
#
#                 NEWCollabToolsHaveWorkedWith  \
# 17680       Visual Studio;Visual Studio Code
# 5514   Android Studio;IntelliJ IDEA;WebStorm
# 28602       Visual Studio;Visual Studio Code
# 61184                                    NaN
# 24416              Neovim;Visual Studio Code
# 29761           Android Studio;Fleet;PyCharm
# 48874                                    NaN
# 63768                                    NaN
# 58267                     Visual Studio Code
# 24016   IntelliJ IDEA;Netbeans;Notepad++;Vim
#
#                             NEWCollabToolsWantToWorkWith  \
# 17680                   Visual Studio;Visual Studio Code
# 5514   Android Studio;IntelliJ IDEA;Visual Studio Cod...
# 28602                   Visual Studio;Visual Studio Code
# 61184                                                NaN
# 24416                    CLion;Neovim;Visual Studio Code
# 29761                       Android Studio;Fleet;PyCharm
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                        NEWCollabToolsAdmired  \
# 17680       Visual Studio;Visual Studio Code
# 5514   Android Studio;IntelliJ IDEA;WebStorm
# 28602       Visual Studio;Visual Studio Code
# 61184                                    NaN
# 24416              Neovim;Visual Studio Code
# 29761           Android Studio;Fleet;PyCharm
# 48874                                    NaN
# 63768                                    NaN
# 58267                                    NaN
# 24016                                    NaN
#
#                                        OpSysPersonal use  \
# 17680                                              MacOS
# 5514                                   Android;iOS;MacOS
# 28602                                            Windows
# 61184                                                NaN
# 24416  Fedora;Ubuntu;Windows;Windows Subsystem for Li...
# 29761                                              MacOS
# 48874                                  Debian;iOS;Ubuntu
# 63768                                                NaN
# 58267                                     Ubuntu;Windows
# 24016                                            Windows
#
#                                    OpSysProfessional use  \
# 17680                                              MacOS
# 5514                                   Android;iOS;MacOS
# 28602                                            Windows
# 61184                                                NaN
# 24416             Android;MacOS;Other Linux-based;Ubuntu
# 29761                                              MacOS
# 48874                                                NaN
# 63768                                                NaN
# 58267                                              MacOS
# 24016  Red Hat;Windows;Windows Subsystem for Linux (WSL)
#
#                           OfficeStackAsyncHaveWorkedWith  \
# 17680                                               Jira
# 5514                                    Jira;Miro;Notion
# 28602                                       Azure Devops
# 61184                                                NaN
# 24416  Confluence;Jira;Markdown File;Stack Overflow f...
# 29761                                             Trello
# 48874                         Doxygen;GitHub Discussions
# 63768                                                NaN
# 58267                      Confluence;GitHub Discussions
# 24016                                    Confluence;Jira
#
#       OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# 17680                           Jira                    Jira
# 5514                Jira;Miro;Notion        Jira;Miro;Notion
# 28602                   Azure Devops            Azure Devops
# 61184                            NaN                     NaN
# 24416         Markdown File;Obsidian           Markdown File
# 29761                           Jira                     NaN
# 48874                            NaN                     NaN
# 63768                            NaN                     NaN
# 58267                            NaN                     NaN
# 24016                            NaN                     NaN
#
#                            OfficeStackSyncHaveWorkedWith  \
# 17680  Discord;Google Chat;Google Meet;Mattermost;Sla...
# 5514                                          Slack;Zoom
# 28602             Discord;Microsoft Teams;Slack;Whatsapp
# 61184                                                NaN
# 24416                      Google Chat;Google Meet;Slack
# 29761                                        Google Meet
# 48874                                                NaN
# 63768                                                NaN
# 58267                                    Microsoft Teams
# 24016                               Microsoft Teams;Zoom
#
#                            OfficeStackSyncWantToWorkWith  \
# 17680  Discord;Google Chat;Google Meet;Slack;Whatsapp...
# 5514                                          Slack;Zoom
# 28602                                            Discord
# 61184                                                NaN
# 24416                                                NaN
# 29761                                         Slack;Zoom
# 48874                                                NaN
# 63768                                                NaN
# 58267                                              Slack
# 24016                                                NaN
#
#                                   OfficeStackSyncAdmired  \
# 17680  Discord;Google Chat;Google Meet;Slack;Whatsapp...
# 5514                                          Slack;Zoom
# 28602                                            Discord
# 61184                                                NaN
# 24416                                                NaN
# 29761                                                NaN
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                                AISearchDevHaveWorkedWith  \
# 17680  Bing AI;ChatGPT;Claude;GitHub Copilot;Google G...
# 5514                                             ChatGPT
# 28602                             Bing AI;ChatGPT;Claude
# 61184                                                NaN
# 24416                                                NaN
# 29761                      ChatGPT;Perplexity AI;Tabnine
# 48874        Bing AI;ChatGPT;GitHub Copilot;OpenAI Codex
# 63768                                                NaN
# 58267                              ChatGPT;Google Gemini
# 24016                                            ChatGPT
#
#                                AISearchDevWantToWorkWith  \
# 17680  Bing AI;ChatGPT;Claude;GitHub Copilot;Google G...
# 5514                               ChatGPT;Google Gemini
# 28602                                                NaN
# 61184                                                NaN
# 24416                                                NaN
# 29761                              ChatGPT;Perplexity AI
# 48874                                                NaN
# 63768                                                NaN
# 58267                                     GitHub Copilot
# 24016                                                NaN
#
#                                       AISearchDevAdmired  \
# 17680  Bing AI;ChatGPT;Claude;GitHub Copilot;Google G...
# 5514                                             ChatGPT
# 28602                                                NaN
# 61184                                                NaN
# 24416                                                NaN
# 29761                              ChatGPT;Perplexity AI
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                                               NEWSOSites  \
# 17680                                     Stack Overflow
# 5514                       Stack Overflow;Stack Exchange
# 28602                      Stack Overflow;Stack Exchange
# 61184                                     Stack Overflow
# 24416  Stack Overflow;Stack Exchange;Stack Overflow B...
# 29761                      Stack Overflow;Stack Exchange
# 48874         Stack Overflow;Stack Exchange;Overflow API
# 63768  Stack Overflow;Stack Exchange;Stack Overflow B...
# 58267                                     Stack Overflow
# 24016                      Stack Overflow;Stack Exchange
#
#                                SOVisitFreq                SOAccount  \
# 17680      A few times per month or weekly                      Yes
# 5514                  A few times per week                      Yes
# 28602                 A few times per week                      Yes
# 61184                 A few times per week                      Yes
# 24416      A few times per month or weekly                      Yes
# 29761                 A few times per week                      Yes
# 48874  Less than once per month or monthly  Not sure/can't remember
# 63768                Daily or almost daily                      Yes
# 58267               Multiple times per day                      Yes
# 24016                Daily or almost daily                      Yes
#
#                                               SOPartFreq  \
# 17680                Less than once per month or monthly
# 5514                     A few times per month or weekly
# 28602  I have never participated in Q&A on Stack Over...
# 61184                Less than once per month or monthly
# 24416  I have never participated in Q&A on Stack Over...
# 29761                Less than once per month or monthly
# 48874                                                NaN
# 63768  I have never participated in Q&A on Stack Over...
# 58267                    A few times per month or weekly
# 24016                Less than once per month or monthly
#
#                                                    SOHow          SOComm  \
# 17680  Quickly finding code solutions;Finding reliabl...  No, not really
# 5514   Quickly finding code solutions;Learning new-to...   Yes, somewhat
# 28602  Quickly finding code solutions;Finding reliabl...  No, not really
# 61184                     Quickly finding code solutions  No, not really
# 24416  Quickly finding code solutions;Finding reliabl...  No, not really
# 29761  Quickly finding code solutions;Finding reliabl...  No, not really
# 48874  Engage with community by commenting on questio...  No, not really
# 63768  Quickly finding code solutions;Learning new-to...         Neutral
# 58267  Finding reliable guidance from community-vette...   Yes, somewhat
# 24016  Quickly finding code solutions;Finding reliabl...   Yes, somewhat
#
#                       AISelect          AISent  \
# 17680                      Yes  Very favorable
# 5514                       Yes       Favorable
# 28602                      Yes     Indifferent
# 61184                      Yes       Favorable
# 24416  No, and I don't plan to             NaN
# 29761                      Yes       Favorable
# 48874                      Yes     Indifferent
# 63768                      NaN             NaN
# 58267   No, but I plan to soon       Favorable
# 24016   No, but I plan to soon          Unsure
#
#                                                    AIBen  \
# 17680  Increase productivity;Greater efficiency;Speed...
# 5514    Increase productivity;Improve accuracy in coding
# 28602                                  Speed up learning
# 61184    Speed up learning;Make workload more manageable
# 24416                                                NaN
# 29761  Increase productivity;Greater efficiency;Speed...
# 48874                              Improve collaboration
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                             AIAcc  \
# 17680                Highly trust
# 5514            Somewhat distrust
# 28602  Neither trust nor distrust
# 61184           Somewhat distrust
# 24416                         NaN
# 29761              Somewhat trust
# 48874              Somewhat trust
# 63768                         NaN
# 58267                         NaN
# 24016                         NaN
#
#                                            AIComplex  \
# 17680            Very well at handling complex tasks
# 5514   Neither good or bad at handling complex tasks
# 28602            Very poor at handling complex tasks
# 61184  Neither good or bad at handling complex tasks
# 24416                                            NaN
# 29761  Neither good or bad at handling complex tasks
# 48874  Good, but not great at handling complex tasks
# 63768                                            NaN
# 58267                                            NaN
# 24016                                            NaN
#
#                                    AIToolCurrently Using  \
# 17680  Writing code;Debugging and getting help;Search...
# 5514    Writing code;Documenting code;Search for answers
# 28602  Learning about a codebase;Debugging and gettin...
# 61184  Writing code;Debugging and getting help;Testin...
# 24416                                                NaN
# 29761  Learning about a codebase;Writing code;Debuggi...
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                                AIToolInterested in Using  \
# 17680  Learning about a codebase;Documenting code;Tes...
# 5514   Debugging and getting help;Testing code;Commit...
# 28602                                   Documenting code
# 61184         Learning about a codebase;Documenting code
# 24416                                                NaN
# 29761  Project planning;Documenting code;Committing a...
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                            AIToolNot interested in Using  \
# 17680     Project planning;Committing and reviewing code
# 5514   Learning about a codebase;Project planning;Dep...
# 28602  Project planning;Writing code;Testing code;Com...
# 61184  Project planning;Committing and reviewing code...
# 24416                                                NaN
# 29761                                                NaN
# 48874                          Learning about a codebase
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                               AINextMuch more integrated  \
# 17680  Writing code;Debugging and getting help;Search...
# 5514                                                 NaN
# 28602                                                NaN
# 61184                                       Testing code
# 24416                                                NaN
# 29761  Writing code;Debugging and getting help;Testin...
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#                                          AINextNo change  \
# 17680                                                NaN
# 5514                                                 NaN
# 28602  Learning about a codebase;Debugging and gettin...
# 61184                         Debugging and getting help
# 24416                                                NaN
# 29761                                                NaN
# 48874                                                NaN
# 63768                                                NaN
# 58267                                                NaN
# 24016                                                NaN
#
#            AINextMore integrated AINextLess integrated  \
# 17680                        NaN                   NaN
# 5514                         NaN                   NaN
# 28602                        NaN                   NaN
# 61184               Writing code    Search for answers
# 24416                        NaN                   NaN
# 29761  Learning about a codebase                   NaN
# 48874                        NaN                   NaN
# 63768                        NaN                   NaN
# 58267                        NaN                   NaN
# 24016                        NaN                   NaN
#
#                              AINextMuch less integrated      AIThreat  \
# 17680                                               NaN           Yes
# 5514   Writing code;Documenting code;Search for answers            No
# 28602                                               NaN  I'm not sure
# 61184                                               NaN            No
# 24416                                               NaN           NaN
# 29761                                               NaN           Yes
# 48874                                               NaN            No
# 63768                                               NaN           NaN
# 58267                                               NaN  I'm not sure
# 24016                                               NaN            No
#
#                                                 AIEthics  \
# 17680  Replacing jobs without options for new employm...
# 5514   Circulating misinformation or disinformation;B...
# 28602  Circulating misinformation or disinformation;M...
# 61184                                                NaN
# 24416                                                NaN
# 29761                                                NaN
# 48874  Circulating misinformation or disinformation;I...
# 63768                                                NaN
# 58267  Missing or incorrect attribution for sources o...
# 24016  Missing or incorrect attribution for sources o...
#
#                                             AIChallenges TBranch  \
# 17680  AI tools lack context of codebase,  internal a...     NaN
# 5514                   Don’t trust the output or answers     Yes
# 28602  Don’t trust the output or answers;AI tools lac...     Yes
# 61184                                                NaN     NaN
# 24416                                                NaN      No
# 29761  AI tools lack context of codebase,  internal a...     Yes
# 48874  AI tools lack context of codebase,  internal a...      No
# 63768                                                NaN     NaN
# 58267  AI tools lack context of codebase,  internal a...     Yes
# 24016  Don’t trust the output or answers;AI tools lac...      No
#
#                        ICorPM  WorkExp     Knowledge_1  \
# 17680                     NaN      NaN             NaN
# 5514   Individual contributor      7.0  Strongly agree
# 28602  Individual contributor      6.0           Agree
# 61184                     NaN      NaN             NaN
# 24416                     NaN      NaN             NaN
# 29761  Individual contributor      7.0           Agree
# 48874                     NaN      NaN             NaN
# 63768                     NaN      NaN             NaN
# 58267  Individual contributor      3.0           Agree
# 24016                     NaN      NaN             NaN
#
#                       Knowledge_2                 Knowledge_3  \
# 17680                         NaN                         NaN
# 5514   Neither agree nor disagree                       Agree
# 28602  Neither agree nor disagree                    Disagree
# 61184                         NaN                         NaN
# 24416                         NaN                         NaN
# 29761                       Agree           Strongly disagree
# 48874                         NaN                         NaN
# 63768                         NaN                         NaN
# 58267                         NaN  Neither agree nor disagree
# 24016                         NaN                         NaN
#
#                       Knowledge_4                 Knowledge_5  \
# 17680                         NaN                         NaN
# 5514                        Agree                       Agree
# 28602                    Disagree                    Disagree
# 61184                         NaN                         NaN
# 24416                         NaN                         NaN
# 29761           Strongly disagree           Strongly disagree
# 48874                         NaN                         NaN
# 63768                         NaN                         NaN
# 58267  Neither agree nor disagree  Neither agree nor disagree
# 24016                         NaN                         NaN
#
#                       Knowledge_6                 Knowledge_7  \
# 17680                         NaN                         NaN
# 5514                        Agree  Neither agree nor disagree
# 28602           Strongly disagree                       Agree
# 61184                         NaN                         NaN
# 24416                         NaN                         NaN
# 29761                       Agree                       Agree
# 48874                         NaN                         NaN
# 63768                         NaN                         NaN
# 58267  Neither agree nor disagree  Neither agree nor disagree
# 24016                         NaN                         NaN
#
#                       Knowledge_8        Knowledge_9       Frequency_1  \
# 17680                         NaN                NaN               NaN
# 5514   Neither agree nor disagree              Agree  1-2 times a week
# 28602  Neither agree nor disagree  Strongly disagree             Never
# 61184                         NaN                NaN               NaN
# 24416                         NaN                NaN               NaN
# 29761                    Disagree  Strongly disagree             Never
# 48874                         NaN                NaN               NaN
# 63768                         NaN                NaN               NaN
# 58267  Neither agree nor disagree           Disagree  1-2 times a week
# 24016                         NaN                NaN               NaN
#
#              Frequency_2       Frequency_3               TimeSearching  \
# 17680                NaN               NaN                         NaN
# 5514   6-10 times a week  1-2 times a week        60-120 minutes a day
# 28602              Never  1-2 times a week  Less than 15 minutes a day
# 61184                NaN               NaN                         NaN
# 24416                NaN               NaN                         NaN
# 29761              Never             Never        60-120 minutes a day
# 48874                NaN               NaN                         NaN
# 63768                NaN               NaN                         NaN
# 58267   1-2 times a week  1-2 times a week        60-120 minutes a day
# 24016                NaN               NaN                         NaN
#
#               TimeAnswering  \
# 17680                   NaN
# 5514    30-60 minutes a day
# 28602   15-30 minutes a day
# 61184                   NaN
# 24416                   NaN
# 29761  60-120 minutes a day
# 48874                   NaN
# 63768                   NaN
# 58267  60-120 minutes a day
# 24016                   NaN
#
#                                              Frustration  \
# 17680                                                NaN
# 5514   Amount of technical debt;Maintaining security ...
# 28602  Amount of technical debt;Tracking my work;Show...
# 61184                                                NaN
# 24416                                                NaN
# 29761                           Amount of technical debt
# 48874                                                NaN
# 63768                                                NaN
# 58267  Maintaining security of systems/platforms used...
# 24016                                                NaN
#
#                                         ProfessionalTech  \
# 17680                                                NaN
# 5514   DevOps function;Automated testing;AI-assisted ...
# 28602               Microservices;Innersource initiative
# 61184                                                NaN
# 24416                                                NaN
# 29761  Continuous integration (CI) and (more often) c...
# 48874                                                NaN
# 63768                                                NaN
# 58267  DevOps function;Microservices;Continuous integ...
# 24016                                                NaN
#
#                         ProfessionalCloud              ProfessionalQuestion  \
# 17680                                 NaN                               NaN
# 5514   Cloud only (single or multi-cloud)  Traditional public search engine
# 28602          Hybrid (on-prem and cloud)                        A coworker
# 61184                                 NaN                               NaN
# 24416                                 NaN                               NaN
# 29761  Cloud only (single or multi-cloud)          AI-powered search (free)
# 48874                                 NaN                               NaN
# 63768                                 NaN                               NaN
# 58267          Hybrid (on-prem and cloud)          AI-powered search (free)
# 24016                                 NaN                               NaN
#
#                    Industry  JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  \
# 17680                   NaN             NaN             NaN             NaN
# 5514       Higher Education             4.0             4.0            12.0
# 28602  Software Development            20.0             0.0             0.0
# 61184                   NaN             NaN             NaN             NaN
# 24416                   NaN             NaN             NaN             NaN
# 29761            Healthcare            40.0             0.0             0.0
# 48874                   NaN             NaN             NaN             NaN
# 63768                   NaN             NaN             NaN             NaN
# 58267  Software Development             9.0             6.0             8.0
# 24016                   NaN             NaN             NaN             NaN
#
#        JobSatPoints_6  JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  \
# 17680             NaN             NaN             NaN             NaN
# 5514             18.0            20.0            17.0             5.0
# 28602             0.0             0.0           100.0            50.0
# 61184             NaN             NaN             NaN             NaN
# 24416             NaN             NaN             NaN             NaN
# 29761            20.0            20.0             0.0            20.0
# 48874             NaN             NaN             NaN             NaN
# 63768             NaN             NaN             NaN             NaN
# 58267             8.0             9.0             8.0             8.0
# 24016             NaN             NaN             NaN             NaN
#
#        JobSatPoints_10  JobSatPoints_11           SurveyLength  \
# 17680              NaN              NaN  Appropriate in length
# 5514               8.0             12.0               Too long
# 28602             80.0              0.0               Too long
# 61184              NaN              NaN                    NaN
# 24416              NaN              NaN  Appropriate in length
# 29761              0.0              0.0  Appropriate in length
# 48874              NaN              NaN  Appropriate in length
# 63768              NaN              NaN                    NaN
# 58267              7.0              8.0               Too long
# 24016              NaN              NaN  Appropriate in length
#
#                        SurveyEase  ConvertedCompYearly  JobSat
# 17680                        Easy                  NaN     NaN
# 5514   Neither easy nor difficult              40000.0     8.0
# 28602  Neither easy nor difficult              59553.0     5.0
# 61184                         NaN                  NaN     NaN
# 24416                        Easy             123000.0     NaN
# 29761  Neither easy nor difficult              15140.0     5.0
# 48874  Neither easy nor difficult                  NaN     NaN
# 63768                         NaN                  NaN     NaN
# 58267                   Difficult                  NaN     7.0
# 24016                        Easy             160000.0     NaN

# %%
df.columns.values
# Out:
# array(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'Check', 'CodingActivities', 'EdLevel', 'LearnCode',
#        'LearnCodeOnline', 'TechDoc', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'BuildvsBuy', 'TechEndorse', 'Country', 'Currency', 'CompTotal',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired',
#        'EmbeddedHaveWorkedWith', 'EmbeddedWantToWorkWith',
#        'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'ToolsTechAdmired', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'NEWCollabToolsAdmired',
#        'OpSysPersonal use', 'OpSysProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackAsyncAdmired', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'OfficeStackSyncAdmired',
#        'AISearchDevHaveWorkedWith', 'AISearchDevWantToWorkWith',
#        'AISearchDevAdmired', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOHow', 'SOComm', 'AISelect', 'AISent', 'AIBen',
#        'AIAcc', 'AIComplex', 'AIToolCurrently Using',
#        'AIToolInterested in Using', 'AIToolNot interested in Using',
#        'AINextMuch more integrated', 'AINextNo change',
#        'AINextMore integrated', 'AINextLess integrated',
#        'AINextMuch less integrated', 'AIThreat', 'AIEthics',
#        'AIChallenges', 'TBranch', 'ICorPM', 'WorkExp', 'Knowledge_1',
#        'Knowledge_2', 'Knowledge_3', 'Knowledge_4', 'Knowledge_5',
#        'Knowledge_6', 'Knowledge_7', 'Knowledge_8', 'Knowledge_9',
#        'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
#        'TimeAnswering', 'Frustration', 'ProfessionalTech',
#        'ProfessionalCloud', 'ProfessionalQuestion', 'Industry',
#        'JobSatPoints_1', 'JobSatPoints_4', 'JobSatPoints_5',
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8',
#        'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11',
#        'SurveyLength', 'SurveyEase', 'ConvertedCompYearly', 'JobSat'],
#       dtype=object)

# %%
df.size
# Out:
# 7459818

# %%
df.shape
# Out:
# (65437, 114)

# %%
df.describe(include='all')
# Out:
#           ResponseId                      MainBranch              Age  \
# count   65437.000000                           65437            65437
# unique           NaN                               5                8
# top              NaN  I am a developer by profession  25-34 years old
# freq             NaN                           50207            23911
# mean    32719.000000                             NaN              NaN
# std     18890.179119                             NaN              NaN
# min         1.000000                             NaN              NaN
# 25%     16360.000000                             NaN              NaN
# 50%     32719.000000                             NaN              NaN
# 75%     49078.000000                             NaN              NaN
# max     65437.000000                             NaN              NaN
#
#                  Employment                            RemoteWork   Check  \
# count                 65437                                 54806   65437
# unique                  110                                     3       1
# top     Employed, full-time  Hybrid (some remote, some in-person)  Apples
# freq                  39041                                 23015   65437
# mean                    NaN                                   NaN     NaN
# std                     NaN                                   NaN     NaN
# min                     NaN                                   NaN     NaN
# 25%                     NaN                                   NaN     NaN
# 50%                     NaN                                   NaN     NaN
# 75%                     NaN                                   NaN     NaN
# max                     NaN                                   NaN     NaN
#
#        CodingActivities                                       EdLevel  \
# count             54466                                         60784
# unique              118                                             8
# top               Hobby  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# freq               9993                                         24942
# mean                NaN                                           NaN
# std                 NaN                                           NaN
# min                 NaN                                           NaN
# 25%                 NaN                                           NaN
# 50%                 NaN                                           NaN
# 75%                 NaN                                           NaN
# max                 NaN                                           NaN
#
#                                                 LearnCode  \
# count                                               60488
# unique                                                418
# top     Other online resources (e.g., videos, blogs, f...
# freq                                                 3674
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                           LearnCodeOnline  \
# count                                               49237
# unique                                              10853
# top     Technical documentation;Blogs;Written Tutorial...
# freq                                                  603
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   TechDoc YearsCode  \
# count                                               40897     59869
# unique                                                113        52
# top     API document(s) and/or SDK document(s);User gu...        10
# freq                                                 6947      4561
# mean                                                  NaN       NaN
# std                                                   NaN       NaN
# min                                                   NaN       NaN
# 25%                                                   NaN       NaN
# 50%                                                   NaN       NaN
# 75%                                                   NaN       NaN
# max                                                   NaN       NaN
#
#        YearsCodePro                DevType             OrgSize  \
# count         51610                  59445               47480
# unique           52                     34                  10
# top               2  Developer, full-stack  20 to 99 employees
# freq           4168                  18260                9754
# mean            NaN                    NaN                 NaN
# std             NaN                    NaN                 NaN
# min             NaN                    NaN                 NaN
# 25%             NaN                    NaN                 NaN
# 50%             NaN                    NaN                 NaN
# 75%             NaN                    NaN                 NaN
# max             NaN                    NaN                 NaN
#
#             PurchaseInfluence  \
# count                   47406
# unique                      3
# top     I have some influence
# freq                    19197
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN
#
#                                                BuyNewTool  \
# count                                               45181
# unique                                                215
# top     Start a free trial;Ask developers I know/work ...
# freq                                                 6619
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                BuildvsBuy  \
# count                                               43358
# unique                                                  3
# top     Is ready-to-go but also customizable for growt...
# freq                                                25972
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                               TechEndorse  \
# count                                               43668
# unique                                                386
# top     APIs;Customization;Reputation for quality and ...
# freq                                                 1499
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                          Country           Currency      CompTotal  \
# count                      58930              46684   3.374000e+04
# unique                       185                142            NaN
# top     United States of America  EUR European Euro            NaN
# freq                       11095              12730            NaN
# mean                         NaN                NaN  2.963841e+145
# std                          NaN                NaN  5.444117e+147
# min                          NaN                NaN   0.000000e+00
# 25%                          NaN                NaN   6.000000e+04
# 50%                          NaN                NaN   1.100000e+05
# 75%                          NaN                NaN   2.500000e+05
# max                          NaN                NaN  1.000000e+150
#
#                 LanguageHaveWorkedWith LanguageWantToWorkWith LanguageAdmired  \
# count                            59745                  55752           50872
# unique                           23864                  22769           12335
# top     HTML/CSS;JavaScript;TypeScript                 Python          Python
# freq                              1002                    922            1555
# mean                               NaN                    NaN             NaN
# std                                NaN                    NaN             NaN
# min                                NaN                    NaN             NaN
# 25%                                NaN                    NaN             NaN
# 50%                                NaN                    NaN             NaN
# 75%                                NaN                    NaN             NaN
# max                                NaN                    NaN             NaN
#
#        DatabaseHaveWorkedWith DatabaseWantToWorkWith DatabaseAdmired  \
# count                   50254                  42558           38557
# unique                   9050                   8478            4051
# top                PostgreSQL             PostgreSQL      PostgreSQL
# freq                     3216                   3738            4894
# mean                      NaN                    NaN             NaN
# std                       NaN                    NaN             NaN
# min                       NaN                    NaN             NaN
# 25%                       NaN                    NaN             NaN
# 50%                       NaN                    NaN             NaN
# 75%                       NaN                    NaN             NaN
# max                       NaN                    NaN             NaN
#
#            PlatformHaveWorkedWith     PlatformWantToWorkWith  \
# count                       42366                      34532
# unique                       5467                       4784
# top     Amazon Web Services (AWS)  Amazon Web Services (AWS)
# freq                         6606                       4859
# mean                          NaN                        NaN
# std                           NaN                        NaN
# min                           NaN                        NaN
# 25%                           NaN                        NaN
# 50%                           NaN                        NaN
# 75%                           NaN                        NaN
# max                           NaN                        NaN
#
#                   PlatformAdmired WebframeHaveWorkedWith  \
# count                       31377                  45161
# unique                       2556                  12235
# top     Amazon Web Services (AWS)                  React
# freq                         6240                   1284
# mean                          NaN                    NaN
# std                           NaN                    NaN
# min                           NaN                    NaN
# 25%                           NaN                    NaN
# 50%                           NaN                    NaN
# 75%                           NaN                    NaN
# max                           NaN                    NaN
#
#        WebframeWantToWorkWith WebframeAdmired EmbeddedHaveWorkedWith  \
# count                   38535           34943                  22214
# unique                  11654            5460                   1630
# top                     React           React            Rasberry Pi
# freq                      997            1422                   3889
# mean                      NaN             NaN                    NaN
# std                       NaN             NaN                    NaN
# min                       NaN             NaN                    NaN
# 25%                       NaN             NaN                    NaN
# 50%                       NaN             NaN                    NaN
# 75%                       NaN             NaN                    NaN
# max                       NaN             NaN                    NaN
#
#        EmbeddedWantToWorkWith EmbeddedAdmired MiscTechHaveWorkedWith  \
# count                   17600           16733                  39443
# unique                   1471            1053                   9288
# top               Rasberry Pi     Rasberry Pi             .NET (5+)
# freq                     3036            3446                   2388
# mean                      NaN             NaN                    NaN
# std                       NaN             NaN                    NaN
# min                       NaN             NaN                    NaN
# 25%                       NaN             NaN                    NaN
# 50%                       NaN             NaN                    NaN
# 75%                       NaN             NaN                    NaN
# max                       NaN             NaN                    NaN
#
#        MiscTechWantToWorkWith MiscTechAdmired ToolsTechHaveWorkedWith  \
# count                   32964           29596                   52482
# unique                  10263            4917                   19883
# top                .NET (5+)       .NET (5+)                   Docker
# freq                     2379            3597                     949
# mean                      NaN             NaN                     NaN
# std                       NaN             NaN                     NaN
# min                       NaN             NaN                     NaN
# 25%                       NaN             NaN                     NaN
# 50%                       NaN             NaN                     NaN
# 75%                       NaN             NaN                     NaN
# max                       NaN             NaN                     NaN
#
#        ToolsTechWantToWorkWith ToolsTechAdmired NEWCollabToolsHaveWorkedWith  \
# count                    46084            43997                        57592
# unique                   16549            11804                        14168
# top                     Docker           Docker           Visual Studio Code
# freq                      1184             1583                         6154
# mean                       NaN              NaN                          NaN
# std                        NaN              NaN                          NaN
# min                        NaN              NaN                          NaN
# 25%                        NaN              NaN                          NaN
# 50%                        NaN              NaN                          NaN
# 75%                        NaN              NaN                          NaN
# max                        NaN              NaN                          NaN
#
#        NEWCollabToolsWantToWorkWith NEWCollabToolsAdmired OpSysPersonal use  \
# count                         52087                 50711             58174
# unique                         9751                  7545              2488
# top              Visual Studio Code    Visual Studio Code           Windows
# freq                           6738                  8235             11514
# mean                            NaN                   NaN               NaN
# std                             NaN                   NaN               NaN
# min                             NaN                   NaN               NaN
# 25%                             NaN                   NaN               NaN
# 50%                             NaN                   NaN               NaN
# 75%                             NaN                   NaN               NaN
# max                             NaN                   NaN               NaN
#
#        OpSysProfessional use OfficeStackAsyncHaveWorkedWith  \
# count                  52973                          48093
# unique                  2032                           6014
# top                  Windows                           Jira
# freq                   10472                           3718
# mean                     NaN                            NaN
# std                      NaN                            NaN
# min                      NaN                            NaN
# 25%                      NaN                            NaN
# 50%                      NaN                            NaN
# 75%                      NaN                            NaN
# max                      NaN                            NaN
#
#        OfficeStackAsyncWantToWorkWith OfficeStackAsyncAdmired  \
# count                           38966                   37204
# unique                           3801                    2661
# top                              Jira                    Jira
# freq                             3047                    3311
# mean                              NaN                     NaN
# std                               NaN                     NaN
# min                               NaN                     NaN
# 25%                               NaN                     NaN
# 50%                               NaN                     NaN
# 75%                               NaN                     NaN
# max                               NaN                     NaN
#
#        OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# count                          55545                         46711
# unique                          5049                          3205
# top                  Microsoft Teams               Microsoft Teams
# freq                            5761                          4326
# mean                             NaN                           NaN
# std                              NaN                           NaN
# min                              NaN                           NaN
# 25%                              NaN                           NaN
# 50%                              NaN                           NaN
# 75%                              NaN                           NaN
# max                              NaN                           NaN
#
#        OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# count                   44712                     44453
# unique                   2555                      2663
# top           Microsoft Teams                   ChatGPT
# freq                     4677                     10799
# mean                      NaN                       NaN
# std                       NaN                       NaN
# min                       NaN                       NaN
# 25%                       NaN                       NaN
# 50%                       NaN                       NaN
# 75%                       NaN                       NaN
# max                       NaN                       NaN
#
#        AISearchDevWantToWorkWith AISearchDevAdmired  \
# count                      36701              35543
# unique                      2361               1488
# top                      ChatGPT            ChatGPT
# freq                        7478              10092
# mean                         NaN                NaN
# std                          NaN                NaN
# min                          NaN                NaN
# 25%                          NaN                NaN
# 50%                          NaN                NaN
# 75%                          NaN                NaN
# max                          NaN                NaN
#
#                            NEWSOSites           SOVisitFreq SOAccount  \
# count                           60286                 59536     59560
# unique                             32                     5         3
# top     Stack Overflow;Stack Exchange  A few times per week       Yes
# freq                            30166                 19238     45453
# mean                              NaN                   NaN       NaN
# std                               NaN                   NaN       NaN
# min                               NaN                   NaN       NaN
# 25%                               NaN                   NaN       NaN
# 50%                               NaN                   NaN       NaN
# 75%                               NaN                   NaN       NaN
# max                               NaN                   NaN       NaN
#
#                                  SOPartFreq  \
# count                                 45237
# unique                                    6
# top     Less than once per month or monthly
# freq                                  24162
# mean                                    NaN
# std                                     NaN
# min                                     NaN
# 25%                                     NaN
# 50%                                     NaN
# 75%                                     NaN
# max                                     NaN
#
#                                                     SOHow          SOComm  \
# count                                               58962           59163
# unique                                                111               6
# top     Quickly finding code solutions;Finding reliabl...  No, not really
# freq                                                13544           17730
# mean                                                  NaN             NaN
# std                                                   NaN             NaN
# min                                                   NaN             NaN
# 25%                                                   NaN             NaN
# 50%                                                   NaN             NaN
# 75%                                                   NaN             NaN
# max                                                   NaN             NaN
#
#        AISelect     AISent                                              AIBen  \
# count     60907      45873                                              36894
# unique        3          6                                                113
# top         Yes  Favorable  Increase productivity;Greater efficiency;Speed...
# freq      37662      22167                                               4391
# mean        NaN        NaN                                                NaN
# std         NaN        NaN                                                NaN
# min         NaN        NaN                                                NaN
# 25%         NaN        NaN                                                NaN
# 50%         NaN        NaN                                                NaN
# 75%         NaN        NaN                                                NaN
# max         NaN        NaN                                                NaN
#
#                  AIAcc                                      AIComplex  \
# count            37302                                          37021
# unique               5                                              5
# top     Somewhat trust  Good, but not great at handling complex tasks
# freq             15039                                          12102
# mean               NaN                                            NaN
# std                NaN                                            NaN
# min                NaN                                            NaN
# 25%                NaN                                            NaN
# 50%                NaN                                            NaN
# 75%                NaN                                            NaN
# max                NaN                                            NaN
#
#                                     AIToolCurrently Using  \
# count                                               35072
# unique                                               1310
# top     Writing code;Debugging and getting help;Search...
# freq                                                 2023
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         AIToolInterested in Using AIToolNot interested in Using  \
# count                       30691                         24414
# unique                       1949                          1531
# top     Learning about a codebase              Project planning
# freq                          598                          1734
# mean                          NaN                           NaN
# std                           NaN                           NaN
# min                           NaN                           NaN
# 25%                           NaN                           NaN
# 50%                           NaN                           NaN
# 75%                           NaN                           NaN
# max                           NaN                           NaN
#
#        AINextMuch more integrated AINextNo change AINextMore integrated  \
# count                       13438           12498                 24428
# unique                        700             539                   884
# top            Search for answers    Writing code          Writing code
# freq                         1426            1852                  2608
# mean                          NaN             NaN                   NaN
# std                           NaN             NaN                   NaN
# min                           NaN             NaN                   NaN
# 25%                           NaN             NaN                   NaN
# 50%                           NaN             NaN                   NaN
# 75%                           NaN             NaN                   NaN
# max                           NaN             NaN                   NaN
#
#        AINextLess integrated AINextMuch less integrated AIThreat  \
# count                   2355                       1148    44689
# unique                   249                        286        3
# top             Writing code               Writing code       No
# freq                     490                        154    30423
# mean                     NaN                        NaN      NaN
# std                      NaN                        NaN      NaN
# min                      NaN                        NaN      NaN
# 25%                      NaN                        NaN      NaN
# 50%                      NaN                        NaN      NaN
# 75%                      NaN                        NaN      NaN
# max                      NaN                        NaN      NaN
#
#                                                  AIEthics  \
# count                                               41548
# unique                                                126
# top     Circulating misinformation or disinformation;M...
# freq                                                 2997
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              AIChallenges TBranch  \
# count                                               37531   44477
# unique                                                232       2
# top     Don’t trust the output or answers;AI tools lac...     Yes
# freq                                                 5502   29960
# mean                                                  NaN     NaN
# std                                                   NaN     NaN
# min                                                   NaN     NaN
# 25%                                                   NaN     NaN
# 50%                                                   NaN     NaN
# 75%                                                   NaN     NaN
# max                                                   NaN     NaN
#
#                         ICorPM       WorkExp Knowledge_1 Knowledge_2  \
# count                    29801  29658.000000       28664       28021
# unique                       2           NaN           5           5
# top     Individual contributor           NaN       Agree       Agree
# freq                     25888           NaN       13454        9060
# mean                       NaN     11.466957         NaN         NaN
# std                        NaN      9.168709         NaN         NaN
# min                        NaN      0.000000         NaN         NaN
# 25%                        NaN      4.000000         NaN         NaN
# 50%                        NaN      9.000000         NaN         NaN
# 75%                        NaN     16.000000         NaN         NaN
# max                        NaN     50.000000         NaN         NaN
#
#        Knowledge_3 Knowledge_4 Knowledge_5 Knowledge_6 Knowledge_7  \
# count        28095       28030       27880       27864       27778
# unique           5           5           5           5           5
# top          Agree       Agree       Agree       Agree       Agree
# freq         10979       12510       14612        9934       10279
# mean           NaN         NaN         NaN         NaN         NaN
# std            NaN         NaN         NaN         NaN         NaN
# min            NaN         NaN         NaN         NaN         NaN
# 25%            NaN         NaN         NaN         NaN         NaN
# 50%            NaN         NaN         NaN         NaN         NaN
# 75%            NaN         NaN         NaN         NaN         NaN
# max            NaN         NaN         NaN         NaN         NaN
#
#        Knowledge_8 Knowledge_9       Frequency_1       Frequency_2  \
# count        27758       27635             28369             28364
# unique           5           5                 5                 5
# top          Agree       Agree  1-2 times a week  1-2 times a week
# freq         10759        6657             16989             12578
# mean           NaN         NaN               NaN               NaN
# std            NaN         NaN               NaN               NaN
# min            NaN         NaN               NaN               NaN
# 25%            NaN         NaN               NaN               NaN
# 50%            NaN         NaN               NaN               NaN
# 75%            NaN         NaN               NaN               NaN
# max            NaN         NaN               NaN               NaN
#
#              Frequency_3        TimeSearching        TimeAnswering  \
# count              27710                28911                28844
# unique                 5                    5                    5
# top     1-2 times a week  30-60 minutes a day  15-30 minutes a day
# freq               14426                10951                 9341
# mean                 NaN                  NaN                  NaN
# std                  NaN                  NaN                  NaN
# min                  NaN                  NaN                  NaN
# 25%                  NaN                  NaN                  NaN
# 50%                  NaN                  NaN                  NaN
# 75%                  NaN                  NaN                  NaN
# max                  NaN                  NaN                  NaN
#
#           Frustration ProfessionalTech           ProfessionalCloud  \
# count           28251            27764                       28491
# unique            954              514                           3
# top     None of these    None of these  Hybrid (on-prem and cloud)
# freq             2364             2834                       13230
# mean              NaN              NaN                         NaN
# std               NaN              NaN                         NaN
# min               NaN              NaN                         NaN
# 25%               NaN              NaN                         NaN
# 50%               NaN              NaN                         NaN
# 75%               NaN              NaN                         NaN
# max               NaN              NaN                         NaN
#
#                     ProfessionalQuestion              Industry  \
# count                              28807                 28858
# unique                                 9                    15
# top     Traditional public search engine  Software Development
# freq                               15813                 11918
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         JobSatPoints_1  JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  \
# count     29324.000000    29393.000000    29411.000000    29450.000000
# unique             NaN             NaN             NaN             NaN
# top                NaN             NaN             NaN             NaN
# freq               NaN             NaN             NaN             NaN
# mean         18.581094        7.522140       10.060857       24.343232
# std          25.966221       18.422661       21.833836       27.089360
# min           0.000000        0.000000        0.000000        0.000000
# 25%           0.000000        0.000000        0.000000        0.000000
# 50%          10.000000        0.000000        0.000000       20.000000
# 75%          22.000000        5.000000       10.000000       30.000000
# max         100.000000      100.000000      100.000000      100.000000
#
#         JobSatPoints_7  JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  \
# count      29448.00000    29456.000000    29456.000000     29450.000000
# unique             NaN             NaN             NaN              NaN
# top                NaN             NaN             NaN              NaN
# freq               NaN             NaN             NaN              NaN
# mean          22.96522       20.278165       16.169432        10.955713
# std           27.01774       26.108110       24.845032        22.906263
# min            0.00000        0.000000        0.000000         0.000000
# 25%            0.00000        0.000000        0.000000         0.000000
# 50%           15.00000       10.000000        5.000000         0.000000
# 75%           30.00000       25.000000       20.000000        10.000000
# max          100.00000      100.000000      100.000000       100.000000
#
#         JobSatPoints_11           SurveyLength SurveyEase  \
# count      29445.000000                  56182      56238
# unique              NaN                      3          3
# top                 NaN  Appropriate in length       Easy
# freq                NaN                  38767      30071
# mean           9.953948                    NaN        NaN
# std           21.775652                    NaN        NaN
# min            0.000000                    NaN        NaN
# 25%            0.000000                    NaN        NaN
# 50%            0.000000                    NaN        NaN
# 75%           10.000000                    NaN        NaN
# max          100.000000                    NaN        NaN
#
#         ConvertedCompYearly        JobSat
# count          2.343500e+04  29126.000000
# unique                  NaN           NaN
# top                     NaN           NaN
# freq                    NaN           NaN
# mean           8.615529e+04      6.935041
# std            1.867570e+05      2.088259
# min            1.000000e+00      0.000000
# 25%            3.271200e+04      6.000000
# 50%            6.500000e+04      7.000000
# 75%            1.079715e+05      8.000000
# max            1.625660e+07     10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB

# %%
cleaned_df = df.drop([
       'Knowledge_1','Knowledge_2', 'Knowledge_3', 'Knowledge_4', 'Knowledge_5',
       'Knowledge_6', 'Knowledge_7', 'Knowledge_8', 'Knowledge_9',
       'Frequency_1', 'Frequency_2', 'Frequency_3',
       'JobSatPoints_1', 'JobSatPoints_4', 'JobSatPoints_5',
       'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8',
       'JobSatPoints_9', 'JobSatPoints_10', 'JobSatPoints_11',
                              ], axis=1)

# %%
cleaned_df.shape
# Out:
# (65437, 93)

# %%
cleaned_df.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  \
# 0                                                NaN
# 1  Technical documentation;Blogs;Books;Written Tu...
# 2  Technical documentation;Blogs;Books;Written Tu...
# 3  Stack Overflow;How-to videos;Interactive tutorial
# 4  Technical documentation;Blogs;Written Tutorial...
#
#                                              TechDoc YearsCode YearsCodePro  \
# 0                                                NaN       NaN          NaN
# 1  API document(s) and/or SDK document(s);User gu...        20           17
# 2  API document(s) and/or SDK document(s);User gu...        37           27
# 3                                                NaN         4          NaN
# 4  API document(s) and/or SDK document(s);User gu...         9          NaN
#
#                  DevType OrgSize PurchaseInfluence BuyNewTool BuildvsBuy  \
# 0                    NaN     NaN               NaN        NaN        NaN
# 1  Developer, full-stack     NaN               NaN        NaN        NaN
# 2   Developer Experience     NaN               NaN        NaN        NaN
# 3  Developer, full-stack     NaN               NaN        NaN        NaN
# 4  Developer, full-stack     NaN               NaN        NaN        NaN
#
#   TechEndorse                                            Country Currency  \
# 0         NaN                           United States of America      NaN
# 1         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 2         NaN  United Kingdom of Great Britain and Northern I...      NaN
# 3         NaN                                             Canada      NaN
# 4         NaN                                             Norway      NaN
#
#    CompTotal                             LanguageHaveWorkedWith  \
# 0        NaN                                                NaN
# 1        NaN  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2        NaN                                                 C#
# 3        NaN  C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4        NaN            C++;HTML/CSS;JavaScript;Lua;Python;Rust
#
#                               LanguageWantToWorkWith  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#                                      LanguageAdmired  \
# 0                                                NaN
# 1  Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                 C#
# 3  HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                 C++;HTML/CSS;JavaScript;Lua;Python
#
#             DatabaseHaveWorkedWith      DatabaseWantToWorkWith  \
# 0                              NaN                         NaN
# 1      Dynamodb;MongoDB;PostgreSQL                  PostgreSQL
# 2       Firebase Realtime Database  Firebase Realtime Database
# 3  MongoDB;MySQL;PostgreSQL;SQLite    MongoDB;MySQL;PostgreSQL
# 4                PostgreSQL;SQLite           PostgreSQL;SQLite
#
#               DatabaseAdmired                    PlatformHaveWorkedWith  \
# 0                         NaN                                       NaN
# 1                  PostgreSQL  Amazon Web Services (AWS);Heroku;Netlify
# 2  Firebase Realtime Database                              Google Cloud
# 3    MongoDB;MySQL;PostgreSQL   Amazon Web Services (AWS);Fly.io;Heroku
# 4           PostgreSQL;SQLite                                       NaN
#
#                      PlatformWantToWorkWith  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3          Amazon Web Services (AWS);Vercel
# 4                                       NaN
#
#                             PlatformAdmired  \
# 0                                       NaN
# 1  Amazon Web Services (AWS);Heroku;Netlify
# 2                              Google Cloud
# 3                 Amazon Web Services (AWS)
# 4                                       NaN
#
#                    WebframeHaveWorkedWith            WebframeWantToWorkWith  \
# 0                                     NaN                               NaN
# 1           Express;Next.js;Node.js;React  Express;Htmx;Node.js;React;Remix
# 2                            ASP.NET CORE                      ASP.NET CORE
# 3  jQuery;Next.js;Node.js;React;WordPress      jQuery;Next.js;Node.js;React
# 4                                     NaN                               NaN
#
#                 WebframeAdmired   EmbeddedHaveWorkedWith  \
# 0                           NaN                      NaN
# 1         Express;Node.js;React                      NaN
# 2                  ASP.NET CORE              Rasberry Pi
# 3  jQuery;Next.js;Node.js;React              Rasberry Pi
# 4                           NaN  CMake;Cargo;Rasberry Pi
#
#   EmbeddedWantToWorkWith    EmbeddedAdmired  \
# 0                    NaN                NaN
# 1                    NaN                NaN
# 2            Rasberry Pi        Rasberry Pi
# 3                    NaN                NaN
# 4      CMake;Rasberry Pi  CMake;Rasberry Pi
#
#                             MiscTechHaveWorkedWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                     NumPy;Pandas;Ruff;TensorFlow
# 4                                              NaN
#
#                             MiscTechWantToWorkWith  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                                    MiscTechAdmired  \
# 0                                              NaN
# 1                                              NaN
# 2  .NET (5+) ;.NET Framework (1.0 - 4.8);.NET MAUI
# 3                                              NaN
# 4                                              NaN
#
#                        ToolsTechHaveWorkedWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                               Docker;npm;Pip
# 4                                 APT;Make;npm
#
#                        ToolsTechWantToWorkWith  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                        Docker;Kubernetes;npm
# 4                                     APT;Make
#
#                               ToolsTechAdmired  \
# 0                                          NaN
# 1  Docker;Homebrew;Kubernetes;npm;Vite;Webpack
# 2                                      MSBuild
# 3                                   Docker;npm
# 4                                     APT;Make
#
#           NEWCollabToolsHaveWorkedWith         NEWCollabToolsWantToWorkWith  \
# 0                                  NaN                                  NaN
# 1  PyCharm;Visual Studio Code;WebStorm  PyCharm;Visual Studio Code;WebStorm
# 2                        Visual Studio                        Visual Studio
# 3                                  NaN                                  NaN
# 4                                  Vim                                  Vim
#
#                  NEWCollabToolsAdmired        OpSysPersonal use  \
# 0                                  NaN                      NaN
# 1  PyCharm;Visual Studio Code;WebStorm            MacOS;Windows
# 2                        Visual Studio                  Windows
# 3                                  NaN                      NaN
# 4                                  Vim  Other (please specify):
#
#   OpSysProfessional use                     OfficeStackAsyncHaveWorkedWith  \
# 0                   NaN                                                NaN
# 1                 MacOS                                                NaN
# 2               Windows                                                NaN
# 3                   NaN                                                NaN
# 4                   NaN  GitHub Discussions;Markdown File;Obsidian;Stac...
#
#               OfficeStackAsyncWantToWorkWith  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                      OfficeStackAsyncAdmired  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  GitHub Discussions;Markdown File;Obsidian
#
#                   OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# 0                                           NaN                           NaN
# 1                         Microsoft Teams;Slack                         Slack
# 2  Google Chat;Google Meet;Microsoft Teams;Zoom  Google Chat;Google Meet;Zoom
# 3                                           NaN                           NaN
# 4                              Discord;Whatsapp              Discord;Whatsapp
#
#          OfficeStackSyncAdmired AISearchDevHaveWorkedWith  \
# 0                           NaN                       NaN
# 1                         Slack                       NaN
# 2  Google Chat;Google Meet;Zoom                       NaN
# 3                           NaN                       NaN
# 4              Discord;Whatsapp                       NaN
#
#   AISearchDevWantToWorkWith AISearchDevAdmired  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                           NEWSOSites             SOVisitFreq  \
# 0  I have never visited Stack Overflow or the Sta...                     NaN
# 1  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
# 2  Stack Overflow;Stack Exchange;Stack Overflow B...  Multiple times per day
# 3                                     Stack Overflow   Daily or almost daily
# 4  Stack Overflow for Teams (private knowledge sh...  Multiple times per day
#
#   SOAccount              SOPartFreq  \
# 0       NaN                     NaN
# 1       Yes  Multiple times per day
# 2       Yes  Multiple times per day
# 3        No                     NaN
# 4       Yes  Multiple times per day
#
#                                                SOHow           SOComm  \
# 0                                                NaN              NaN
# 1  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 2  Quickly finding code solutions;Finding reliabl...  Yes, definitely
# 3                     Quickly finding code solutions   No, not really
# 4  Quickly finding code solutions;Engage with com...  Yes, definitely
#
#                   AISelect          AISent  \
# 0                      Yes  Very favorable
# 1  No, and I don't plan to             NaN
# 2  No, and I don't plan to             NaN
# 3                      Yes  Very favorable
# 4  No, and I don't plan to             NaN
#
#                                                AIBen           AIAcc  \
# 0                              Increase productivity             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Increase productivity;Greater efficiency;Impro...  Somewhat trust
# 4                                                NaN             NaN
#
#                        AIComplex  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3  Bad at handling complex tasks
# 4                            NaN
#
#                                AIToolCurrently Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Learning about a codebase;Project planning;Wri...
# 4                                                NaN
#
#                            AIToolInterested in Using  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Testing code;Committing and reviewing code;Pre...
# 4                                                NaN
#
#   AIToolNot interested in Using  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                           AINextMuch more integrated AINextNo change  \
# 0                                                NaN             NaN
# 1                                                NaN             NaN
# 2                                                NaN             NaN
# 3  Learning about a codebase;Project planning;Wri...             NaN
# 4                                                NaN             NaN
#
#   AINextMore integrated AINextLess integrated AINextMuch less integrated  \
# 0                   NaN                   NaN                        NaN
# 1                   NaN                   NaN                        NaN
# 2                   NaN                   NaN                        NaN
# 3                   NaN                   NaN                        NaN
# 4                   NaN                   NaN                        NaN
#
#   AIThreat                                           AIEthics  \
# 0      NaN                                                NaN
# 1      NaN                                                NaN
# 2      NaN                                                NaN
# 3       No  Circulating misinformation or disinformation;M...
# 4      NaN                                                NaN
#
#                         AIChallenges TBranch                  ICorPM  WorkExp  \
# 0                                NaN      No                     NaN      NaN
# 1                                NaN     Yes  Individual contributor     17.0
# 2                                NaN      No                     NaN      NaN
# 3  Don’t trust the output or answers     NaN                     NaN      NaN
# 4                                NaN     NaN                     NaN      NaN
#
#   TimeSearching TimeAnswering Frustration ProfessionalTech ProfessionalCloud  \
# 0           NaN           NaN         NaN              NaN               NaN
# 1           NaN           NaN         NaN              NaN               NaN
# 2           NaN           NaN         NaN              NaN               NaN
# 3           NaN           NaN         NaN              NaN               NaN
# 4           NaN           NaN         NaN              NaN               NaN
#
#   ProfessionalQuestion Industry           SurveyLength SurveyEase  \
# 0                  NaN      NaN                    NaN        NaN
# 1                  NaN      NaN                    NaN        NaN
# 2                  NaN      NaN  Appropriate in length       Easy
# 3                  NaN      NaN               Too long       Easy
# 4                  NaN      NaN              Too short       Easy
#
#    ConvertedCompYearly  JobSat
# 0                  NaN     NaN
# 1                  NaN     NaN
# 2                  NaN     NaN
# 3                  NaN     NaN
# 4                  NaN     NaN

# %%
cleaned_df.loc[cleaned_df['Country'] == 'United States of America', 'Country'] = 'USA'
cleaned_df.loc[cleaned_df['Country'] == 'United Kingdom of Great Britain and Northern Ireland', 'Country'] = 'UK'

# %%
countries = cleaned_df['Country'].value_counts()
countries.head(10)
# Out:
# Country
# USA            11095
# Germany         4947
# India           4231
# UK              3224
# Ukraine         2672
# France          2110
# Canada          2104
# Poland          1534
# Netherlands     1449
# Brazil          1375
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(8, 6), tight_layout=True)
fig.align_titles = True
fig.suptitle('Top 10 Countries')
ax1, ax2 = fig.subplots(1, 2, )
ax1.pie(countries[:10], labels=countries.index[:10], autopct='%2.0f%%', )
ax2.bar(height=countries[:10].values, x=countries.index[:10], color='mediumseagreen')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)
plt.show()
# Out:
# <ipython-input-81-cba2983fe1e0>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=90)

# %%
selected_columns = ['MainBranch', 'Age', 'Country', 'EdLevel', 'Employment', 'CompTotal', 'ConvertedCompYearly', 'Currency', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith', 'LearnCode']
df_selected = cleaned_df[selected_columns]
df_selected
# Out:
#                            MainBranch                 Age  Country  \
# 0      I am a developer by profession  Under 18 years old      USA
# 1      I am a developer by profession     35-44 years old       UK
# 2      I am a developer by profession     45-54 years old       UK
# 3               I am learning to code     18-24 years old   Canada
# 4      I am a developer by profession     18-24 years old   Norway
# ...                               ...                 ...      ...
# 65432  I am a developer by profession     18-24 years old      NaN
# 65433  I am a developer by profession     25-34 years old      NaN
# 65434  I am a developer by profession     25-34 years old      NaN
# 65435  I am a developer by profession     18-24 years old  Germany
# 65436     I code primarily as a hobby     18-24 years old      NaN
#
#                                                  EdLevel           Employment  \
# 0                              Primary/elementary school  Employed, full-time
# 1           Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed, full-time
# 2        Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  Employed, full-time
# 3      Some college/university study without earning ...   Student, full-time
# 4      Secondary school (e.g. American high school, G...   Student, full-time
# ...                                                  ...                  ...
# 65432       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed, full-time
# 65433                                                NaN  Employed, full-time
# 65434       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  Employed, full-time
# 65435  Secondary school (e.g. American high school, G...  Employed, full-time
# 65436                                                NaN   Student, full-time
#
#        CompTotal  ConvertedCompYearly           Currency  \
# 0            NaN                  NaN                NaN
# 1            NaN                  NaN                NaN
# 2            NaN                  NaN                NaN
# 3            NaN                  NaN                NaN
# 4            NaN                  NaN                NaN
# ...          ...                  ...                ...
# 65432        NaN                  NaN                NaN
# 65433        NaN                  NaN                NaN
# 65434        NaN                  NaN                NaN
# 65435        NaN                  NaN  EUR European Euro
# 65436        NaN                  NaN                NaN
#
#                                   LanguageHaveWorkedWith  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;...
# 4                C++;HTML/CSS;JavaScript;Lua;Python;Rust
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435           C;C++;Go;Lua;Objective-C;Python;Rust;SQL
# 65436   C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript
#
#                                   LanguageWantToWorkWith  \
# 0                                                    NaN
# 1      Bash/Shell (all shells);Go;HTML/CSS;Java;JavaS...
# 2                                                     C#
# 3      HTML/CSS;Java;JavaScript;PowerShell;Python;SQL...
# 4                     C++;HTML/CSS;JavaScript;Lua;Python
# ...                                                  ...
# 65432                                                NaN
# 65433                                                NaN
# 65434                                                NaN
# 65435                                           Rust;SQL
# 65436                       JavaScript;Python;TypeScript
#
#                 DatabaseHaveWorkedWith  \
# 0                                  NaN
# 1          Dynamodb;MongoDB;PostgreSQL
# 2           Firebase Realtime Database
# 3      MongoDB;MySQL;PostgreSQL;SQLite
# 4                    PostgreSQL;SQLite
# ...                                ...
# 65432                              NaN
# 65433                              NaN
# 65434                              NaN
# 65435                PostgreSQL;SQLite
# 65436  MongoDB;MySQL;Oracle;PostgreSQL
#
#                                                LearnCode
# 0                                 Books / Physical media
# 1      Books / Physical media;Colleague;On the job tr...
# 2      Books / Physical media;Colleague;On the job tr...
# 3      Other online resources (e.g., videos, blogs, f...
# 4      Other online resources (e.g., videos, blogs, f...
# ...                                                  ...
# 65432  On the job training;School (i.e., University, ...
# 65433                                                NaN
# 65434  Other online resources (e.g., videos, blogs, f...
# 65435  On the job training;Other online resources (e....
# 65436                                                NaN
#
# [65437 rows x 12 columns]

# %%
df_main_branch = df_selected.dropna(subset=['MainBranch'])
df_main_branch['MainBranch'].value_counts()
# Out:
# MainBranch
# I am a developer by profession                                                           50207
# I am not primarily a developer, but I write code sometimes as part of my work/studies     6511
# I am learning to code                                                                     3875
# I code primarily as a hobby                                                               3334
# I used to be a developer by profession, but no longer am                                  1510
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.barh(width=df_main_branch['MainBranch'].value_counts(), y= df_main_branch['MainBranch'].value_counts().index, color='mediumseagreen')
plt.title('MainBranch')
plt.xticks(rotation=45)
plt.show()

# %%
df_ed = df_selected.dropna(subset=['EdLevel'])
print(df_ed['EdLevel'].isna().sum())
df_ed['EdLevel'].value_counts()
# Out:
# 0
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          24942
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15557
# Some college/university study without earning a degree                                 7651
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5793
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2970
# Associate degree (A.A., A.S., etc.)                                                    1793
# Primary/elementary school                                                              1146
# Something else                                                                          932
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.pie(df_selected['EdLevel'].value_counts(), labels=df_selected['EdLevel'].value_counts().index, autopct='%2.0f%%', )
plt.show()

# %%
df_age = df_selected.dropna(subset=['Age'])
df_age_counts = df_age['Age'].value_counts()
df_age_counts
# Out:
# Age
# 25-34 years old       23911
# 35-44 years old       14942
# 18-24 years old       14098
# 45-54 years old        6249
# 55-64 years old        2575
# Under 18 years old     2568
# 65 years or older       772
# Prefer not to say       322
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.pie(df_age_counts, labels=df_age_counts.index, autopct='%2.0f%%', radius=1.2)

plt.xticks(rotation=45)
plt.show()

# %%
df_employment = df_selected.dropna(subset=['Employment'])
df_employment_counts = df_employment['Employment'].value_counts()
df_employment_counts
# Out:
# Employment
# Employed, full-time                                                                                                                                  39041
# Independent contractor, freelancer, or self-employed                                                                                                  4846
# Student, full-time                                                                                                                                    4709
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                              3557
# Not employed, but looking for work                                                                                                                    2341
#                                                                                                                                                      ...
# Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time;Retired               1
# Employed, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Retired                                                      1
# Employed, full-time;Independent contractor, freelancer, or self-employed;Employed, part-time;Retired                                                     1
# Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work        1
# Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Retired                                       1
# Name: count, Length: 110, dtype: int64

# %%
plt.figure(figsize=(10, 6))
plt.pie(df_employment_counts[df_employment_counts.values >= 500], labels=df_employment_counts[df_employment_counts.values >= 500].index, autopct='%2.0f%%', radius=1.4)
plt.show()

# %%
lang_to_learn_df = df_selected.dropna(subset=['LanguageWantToWorkWith'])
selected_cleaned_df = lang_to_learn_df['LanguageWantToWorkWith'].value_counts().reset_index()

# %%
selected_cleaned_df.columns = ['LanguageWantToWorkWith', 'Count']
selected_cleaned_df['Count']
# Out:
# 0        922
# 1        737
# 2        632
# 3        538
# 4        460
#         ...
# 22764      1
# 22765      1
# 22766      1
# 22767      1
# 22768      1
# Name: Count, Length: 22769, dtype: int64

# %%
selected_cleaned_df.loc[selected_cleaned_df['Count'] > 300]
# Out:
#                   LanguageWantToWorkWith  Count
# 0                                 Python    922
# 1                                   Rust    737
# 2         HTML/CSS;JavaScript;TypeScript    632
# 3                                     C#    538
# 4                                     Go    460
# 5                                   Java    331
# 6  C#;HTML/CSS;JavaScript;SQL;TypeScript    317
# 7                             Python;SQL    312

# %%
plt.figure(figsize=(10, 6))
plt.pie(selected_cleaned_df.loc[selected_cleaned_df['Count'] > 300]['Count'],
        labels=selected_cleaned_df.loc[selected_cleaned_df['Count'] > 300]['LanguageWantToWorkWith'],
        autopct='%2.0f%%', )
plt.title('LanguageWantToWorkWith')
plt.show()

# %%
df_selected.dropna(subset=['CompTotal'])
# Out:
#                                               MainBranch              Age  \
# 72                        I am a developer by profession  18-24 years old
# 374    I am not primarily a developer, but I write co...  25-34 years old
# 379                       I am a developer by profession  35-44 years old
# 385                       I am a developer by profession  35-44 years old
# 389                       I am a developer by profession  25-34 years old
# ...                                                  ...              ...
# 65396                     I am a developer by profession  18-24 years old
# 65401                     I am a developer by profession  25-34 years old
# 65408                     I am a developer by profession  25-34 years old
# 65412                     I am a developer by profession  35-44 years old
# 65431                     I am a developer by profession  45-54 years old
#
#          Country                                            EdLevel  \
# 72      Pakistan  Secondary school (e.g. American high school, G...
# 374      Austria     Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 379       Turkey    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 385       France    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 389          USA  Some college/university study without earning ...
# ...          ...                                                ...
# 65396  Lithuania  Secondary school (e.g. American high school, G...
# 65401     France       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65408     France    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65412      Italy       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65431    Belgium       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                               Employment  CompTotal  \
# 72     Employed, full-time;Student, full-time;Indepen...  2040000.0
# 374                                  Employed, full-time    28000.0
# 379                                  Employed, full-time    85000.0
# 385    Independent contractor, freelancer, or self-em...    50000.0
# 389               Employed, full-time;Student, part-time   110000.0
# ...                                                  ...        ...
# 65396  Employed, full-time;Independent contractor, fr...    36000.0
# 65401                                Employed, full-time    40000.0
# 65408                                Employed, full-time    61000.0
# 65412                                Employed, full-time    58000.0
# 65431                                Employed, full-time    55000.0
#
#        ConvertedCompYearly                   Currency  \
# 72                  7322.0       PKR\tPakistani rupee
# 374                30074.0          EUR European Euro
# 379                91295.0          EUR European Euro
# 385                53703.0          EUR European Euro
# 389               110000.0  USD\tUnited States dollar
# ...                    ...                        ...
# 65396                  NaN          EUR European Euro
# 65401                  NaN          EUR European Euro
# 65408                  NaN          EUR European Euro
# 65412                  NaN          EUR European Euro
# 65431                  NaN          EUR European Euro
#
#                                   LanguageHaveWorkedWith  \
# 72     Assembly;Bash/Shell (all shells);C;C++;HTML/CS...
# 374                      C;C++;Fortran;MATLAB;Python;SQL
# 379               JavaScript;Julia;Python;SQL;TypeScript
# 385                                               Python
# 389            HTML/CSS;JavaScript;Python;SQL;TypeScript
# ...                                                  ...
# 65396      HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 65401              C#;HTML/CSS;JavaScript;SQL;TypeScript
# 65408                  Groovy;Java;JavaScript;Python;SQL
# 65412                                        Java;Kotlin
# 65431  Bash/Shell (all shells);C;C#;C++;Delphi;Groovy...
#
#                                   LanguageWantToWorkWith  \
# 72                                         C#;Rust;Scala
# 374                              C;C++;MATLAB;Python;SQL
# 379             Go;JavaScript;Python;Rust;SQL;TypeScript
# 385                                    Python;Rust;Scala
# 389                                        Go;Rust;Swift
# ...                                                  ...
# 65396              HTML/CSS;JavaScript;Python;TypeScript
# 65401       C#;HTML/CSS;JavaScript;Python;SQL;TypeScript
# 65408                                         Python;SQL
# 65412                                                NaN
# 65431  Bash/Shell (all shells);C#;Go;HTML/CSS;Java;Ja...
#
#                                   DatabaseHaveWorkedWith  \
# 72                                  MongoDB;MySQL;SQLite
# 374                                           PostgreSQL
# 379                             DuckDB;PostgreSQL;SQLite
# 385                BigQuery;MongoDB;PostgreSQL;Snowflake
# 389                                 IBM DB2;MySQL;SQLite
# ...                                                  ...
# 65396                                   MySQL;PostgreSQL
# 65401                                           Couch DB
# 65408                            PostgreSQL;Redis;SQLite
# 65412                             Elasticsearch;H2;MySQL
# 65431  Couch DB;H2;Microsoft SQL Server;MySQL;Oracle;...
#
#                                                LearnCode
# 72     On the job training;Other online resources (e....
# 374    Books / Physical media;Colleague;On the job tr...
# 379    Books / Physical media;Other online resources ...
# 385    Books / Physical media;On the job training;Oth...
# 389    Books / Physical media;Colleague;On the job tr...
# ...                                                  ...
# 65396  Other online resources (e.g., videos, blogs, f...
# 65401  Colleague;On the job training;Other online res...
# 65408  On the job training;Other online resources (e....
# 65412  Books / Physical media;Online Courses or Certi...
# 65431  Books / Physical media;Colleague;On the job tr...
#
# [33740 rows x 12 columns]

# %%
df_learn_method = df_selected.dropna(subset=['LearnCode'])
df_learn_method['LearnCode'].value_counts()[:20]
# Out:
# LearnCode
# Other online resources (e.g., videos, blogs, forum, online community)                                                                                                                                 3674
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)                                                                                                          2493
# Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                                                                         2362
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                                          2286
# Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                                                                 2182
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                                                  1925
# Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification              1879
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification                                  1629
# On the job training;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                                             1600
# Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                      1568
# On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                                                     1529
# On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification                                     1481
# Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification                                                         1458
# On the job training;Other online resources (e.g., videos, blogs, forum, online community)                                                                                                             1438
# School (i.e., University, College, etc)                                                                                                                                                               1434
# Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                              1274
# Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification    1180
# Books / Physical media;On the job training;Other online resources (e.g., videos, blogs, forum, online community)                                                                                      1134
# Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                             842
# Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                     636
# Name: count, dtype: int64

# %%
plt.figure(figsize=(14, 10))
sns.barplot(y=df_learn_method['LearnCode'].value_counts().index[:20],
            x=df_learn_method['LearnCode'].value_counts()[:20],
            hue=df_learn_method['LearnCode'].value_counts().index[:20],
            )
plt.show()

# %%
salary_by_currency = df_selected.dropna(subset=['Currency', 'ConvertedCompYearly', 'CompTotal'])
salary_in_usa = salary_by_currency[(salary_by_currency['Currency'] == 'USD\tUnited States dollar') & (salary_by_currency['ConvertedCompYearly'] > 100) & (salary_by_currency['ConvertedCompYearly'] < 2500000)]
salary_in_usa.sort_values(by='ConvertedCompYearly', ascending=False, inplace=True)
salary_in_usa.loc[salary_in_usa['ConvertedCompYearly'] == salary_in_usa['ConvertedCompYearly'].max()]
# Out:
# <ipython-input-52-87ee3a228384>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salary_in_usa.sort_values(by='ConvertedCompYearly', ascending=False, inplace=True)
#                                               MainBranch              Age  \
# 2187                      I am a developer by profession  35-44 years old
# 27902  I am not primarily a developer, but I write co...  25-34 years old
#
#         Country                                       EdLevel  \
# 2187      Gabon  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 27902  Pakistan  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                 Employment  CompTotal  ConvertedCompYearly  \
# 2187   Employed, full-time  2000000.0            2000000.0
# 27902  Employed, part-time  2000000.0            2000000.0
#
#                         Currency  \
# 2187   USD\tUnited States dollar
# 27902  USD\tUnited States dollar
#
#                                   LanguageHaveWorkedWith  \
# 2187   Bash/Shell (all shells);JavaScript;Python;Rust...
# 27902  Crystal;Go;Java;JavaScript;PowerShell;Ruby;Rus...
#
#                                   LanguageWantToWorkWith  \
# 2187           Assembly;Bash/Shell (all shells);Rust;Zig
# 27902  Ada;Apex;Assembly;Bash/Shell (all shells);C;C#...
#
#                                   DatabaseHaveWorkedWith  \
# 2187                                            InfluxDB
# 27902  Clickhouse;Couch DB;DuckDB;Dynamodb;Elasticsea...
#
#                                                LearnCode
# 2187   On the job training;Other online resources (e....
# 27902                            Friend or family member

# %%
import matplotlib.ticker as ticker

def custom_format(x, pos):
    return f'{int(x):,}'

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.scatterplot(data=salary_in_usa, y='ConvertedCompYearly', x='Age', hue='EdLevel', )
plt.xticks(rotation=45)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(custom_format))
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.show()
